# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
import time
#from config import api_key

#print(api_key)

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/forecast?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid=c307a28aeb926aea5ca576d761bc611b&units={units}&q="

# %%
cities = ['Kabul',
'Tirana ',
'Algiers',
'Andorra la Vella',
'Luanda',
'Saint John\'s',
'Buenos Aires',
'Yerevan',
'Canberra',
'Vienna',
'Baku',
'Nassau',
'Manama',
'Dhaka',
'Bridgetown',
'Minsk',
'Brussels',
'Belmopan',
'Porto Novo',
'Thimphu',
'La Paz',
'Sarajevo',
'Gaborone',
'Brasilia',
'Bandar Seri Begawan',
'Sofia',
'Ouagadougou',
'Gitega',
'Phnom Penh',
'Yaounde',
'Ottawa',
'Praia',
'Bangui',
'N\'Djamena',
'Santiago',
'Beijing',
'Bogota',
'Moroni',
'Kinshasa',
'Brazzaville',
'San Jose',
'Yamoussoukro',
'Zagreb',
'Havana',
'Nicosia',
'Prague',
'Copenhagen',
'Djibouti',
'Roseau',
'Santo Domingo',
'Dili',
'Quito',
'Cairo',
'San Salvador',
'London',
'Malabo',
'Asmara',
'Tallinn',
'Mbabana',
'Addis Ababa',
'Palikir',
'Suva',
'Helsinki',
'Paris',
'Cayenne',
'Libreville',
'Banjul',
'Tbilisi',
'Berlin',
'Accra',
'Athens',
'Saint George\'s',
'Guatemala City',
'Conakry',
'Bissau',
'Georgetown',
'Port au Prince',
'Tegucigalpa',
'Budapest',
'Reykjavik',
'New Delhi',
'Jakarta',
'Tehran',
'Baghdad',
'Dublin',
'Tel Aviv ',
'Rome',
'Kingston',
'Tokyo',
'Amman',
'Astana',
'Nairobi',
'Tarawa Atoll',
'Pristina',
'Kuwait City',
'Bishkek',
'Vientiane',
'Riga',
'Beirut',
'Maseru',
'Monrovia',
'Tripoli',
'Vaduz',
'Vilnius',
'Luxembourg',
'Antananarivo',
'Lilongwe',
'Kuala Lumpur',
'Male',
'Bamako',
'Valletta',
'Majuro',
'Nouakchott',
'Port Louis',
'Mexico City',
'Chisinau',
'Monaco',
'Ulaanbaatar',
'Podgorica',
'Rabat',
'Maputo',
'Nay Pyi Taw',
'Windhoek',
'No official capital',
'Kathmandu',
'Amsterdam',
'Wellington',
'Managua',
'Niamey',
'Abuja',
'Pyongyang',
'Skopje',
'Belfast',
'Oslo',
'Muscat',
'Islamabad',
'Melekeok',
'Panama City',
'Port Moresby',
'Asuncion',
'Lima',
'Manila',
'Warsaw',
'Lisbon',
'Doha',
'Bucharest',
'Moscow',
'Kigali',
'Basseterre',
'Castries',
'Kingstown',
'Apia',
'San Marino',
'Sao Tome',
'Riyadh',
'Edinburgh',
'Dakar',
'Belgrade',
'Victoria',
'Freetown',
'Singapore',
'Bratislava',
'Ljubljana',
'Honiara',
'Mogadishu',
'Pretoria, Bloemfontein, Cape Town',
'Seoul',
'Juba',
'Madrid',
'Colombo',
'Khartoum',
'Paramaribo',
'Stockholm',
'Bern',
'Damascus',
'Taipei',
'Dushanbe',
'Dodoma',
'Bangkok',
'Lome',
'Nuku\'alofa',
'Port of Spain',
'Tunis',
'Ankara',
'Ashgabat',
'Funafuti',
'Kampala',
'Kiev',
'Abu Dhabi',
'London',
'Washington D.C.',
'Montevideo',
'Tashkent',
'Port Vila',
'Vatican City',
'Caracas',
'Hanoi',
'Cardiff',
'Sana\'a',
'Lusaka',
'Harare'
]

# %%
len(cities)
# Out:
# 201

# %%
# set up lists to hold reponse info
city_id = []
city_name = []
city_lat = []
city_lon = []
country = []
city_time = []

# define day_one_time_one arrays
date_one_time_one = []
date_one_time_one_temp = []
date_one_time_one_temp_min = []
date_one_time_one_temp_max =[]
date_one_time_one_pressure = []
date_one_time_one_sea_level = []
date_one_time_one_grnd_level = []
date_one_time_one_humidity = []
date_one_time_one_wind_speed = []
date_one_time_one_wind_direction = []

# define day_one_time_two arrays
date_one_time_two = []
date_one_time_two_temp = []
date_one_time_two_temp_min = []
date_one_time_two_temp_max =[]
date_one_time_two_pressure = []
date_one_time_two_sea_level = []
date_one_time_two_grnd_level = []
date_one_time_two_humidity = []
date_one_time_two_wind_speed = []
date_one_time_two_wind_direction = []


# define day_one_time_three arrays
date_one_time_three = []
date_one_time_three_temp = []
date_one_time_three_temp_min = []
date_one_time_three_temp_max =[]
date_one_time_three_pressure = []
date_one_time_three_sea_level = []
date_one_time_three_grnd_level = []
date_one_time_three_humidity = []
date_one_time_three_wind_speed = []
date_one_time_three_wind_direction = []

# define day_one_time_four arrays
date_one_time_four = []
date_one_time_four_temp = []
date_one_time_four_temp_min = []
date_one_time_four_temp_max =[]
date_one_time_four_pressure = []
date_one_time_four_sea_level = []
date_one_time_four_grnd_level = []
date_one_time_four_humidity = []
date_one_time_four_wind_speed = []
date_one_time_four_wind_direction = []

# define day_one_time_five arrays
date_one_time_five = []
date_one_time_five_temp = []
date_one_time_five_temp_min = []
date_one_time_five_temp_max =[]
date_one_time_five_pressure = []
date_one_time_five_sea_level = []
date_one_time_five_grnd_level = []
date_one_time_five_humidity = []
date_one_time_five_wind_speed = []
date_one_time_five_wind_direction = []

# define day_one_time_six arrays
date_one_time_six = []
date_one_time_six_temp = []
date_one_time_six_temp_min = []
date_one_time_six_temp_max =[]
date_one_time_six_pressure = []
date_one_time_six_sea_level = []
date_one_time_six_grnd_level = []
date_one_time_six_humidity = []
date_one_time_six_wind_speed = []
date_one_time_six_wind_direction = []

# define day_two_time_one arrays
date_two_time_one = []
date_two_time_one_temp = []
date_two_time_one_temp_min = []
date_two_time_one_temp_max =[]
date_two_time_one_pressure = []
date_two_time_one_sea_level = []
date_two_time_one_grnd_level = []
date_two_time_one_humidity = []
date_two_time_one_wind_speed = []
date_two_time_one_wind_direction = []

# define day_two_time_two arrays
date_two_time_two = []
date_two_time_two_temp = []
date_two_time_two_temp_min = []
date_two_time_two_temp_max =[]
date_two_time_two_pressure = []
date_two_time_two_sea_level = []
date_two_time_two_grnd_level = []
date_two_time_two_humidity = []
date_two_time_two_wind_speed = []
date_two_time_two_wind_direction = []


# define day_two_time_three arrays
date_two_time_three = []
date_two_time_three_temp = []
date_two_time_three_temp_min = []
date_two_time_three_temp_max =[]
date_two_time_three_pressure = []
date_two_time_three_sea_level = []
date_two_time_three_grnd_level = []
date_two_time_three_humidity = []
date_two_time_three_wind_speed = []
date_two_time_three_wind_direction = []

# define day_two_time_four arrays
date_two_time_four = []
date_two_time_four_temp = []
date_two_time_four_temp_min = []
date_two_time_four_temp_max =[]
date_two_time_four_pressure = []
date_two_time_four_sea_level = []
date_two_time_four_grnd_level = []
date_two_time_four_humidity = []
date_two_time_four_wind_speed = []
date_two_time_four_wind_direction = []

# define day_two_time_five arrays
date_two_time_five = []
date_two_time_five_temp = []
date_two_time_five_temp_min = []
date_two_time_five_temp_max =[]
date_two_time_five_pressure = []
date_two_time_five_sea_level = []
date_two_time_five_grnd_level = []
date_two_time_five_humidity = []
date_two_time_five_wind_speed = []
date_two_time_five_wind_direction = []

# define day_two_time_six arrays
date_two_time_six = []
date_two_time_six_temp = []
date_two_time_six_temp_min = []
date_two_time_six_temp_max =[]
date_two_time_six_pressure = []
date_two_time_six_sea_level = []
date_two_time_six_grnd_level = []
date_two_time_six_humidity = []
date_two_time_six_wind_speed = []
date_two_time_six_wind_direction = []

# define day_three_time_one arrays
date_three_time_one = []
date_three_time_one_temp = []
date_three_time_one_temp_min = []
date_three_time_one_temp_max =[]
date_three_time_one_pressure = []
date_three_time_one_sea_level = []
date_three_time_one_grnd_level = []
date_three_time_one_humidity = []
date_three_time_one_wind_speed = []
date_three_time_one_wind_direction = []

# define day_three_time_two arrays
date_three_time_two = []
date_three_time_two_temp = []
date_three_time_two_temp_min = []
date_three_time_two_temp_max =[]
date_three_time_two_pressure = []
date_three_time_two_sea_level = []
date_three_time_two_grnd_level = []
date_three_time_two_humidity = []
date_three_time_two_wind_speed = []
date_three_time_two_wind_direction = []


# define day_three_time_three arrays
date_three_time_three = []
date_three_time_three_temp = []
date_three_time_three_temp_min = []
date_three_time_three_temp_max =[]
date_three_time_three_pressure = []
date_three_time_three_sea_level = []
date_three_time_three_grnd_level = []
date_three_time_three_humidity = []
date_three_time_three_wind_speed = []
date_three_time_three_wind_direction = []

# define day_three_time_four arrays
date_three_time_four = []
date_three_time_four_temp = []
date_three_time_four_temp_min = []
date_three_time_four_temp_max =[]
date_three_time_four_pressure = []
date_three_time_four_sea_level = []
date_three_time_four_grnd_level = []
date_three_time_four_humidity = []
date_three_time_four_wind_speed = []
date_three_time_four_wind_direction = []

# define day_three_time_five arrays
date_three_time_five = []
date_three_time_five_temp = []
date_three_time_five_temp_min = []
date_three_time_five_temp_max =[]
date_three_time_five_pressure = []
date_three_time_five_sea_level = []
date_three_time_five_grnd_level = []
date_three_time_five_humidity = []
date_three_time_five_wind_speed = []
date_three_time_five_wind_direction = []

# define day_three_time_six arrays
date_three_time_six = []
date_three_time_six_temp = []
date_three_time_six_temp_min = []
date_three_time_six_temp_max =[]
date_three_time_six_pressure = []
date_three_time_six_sea_level = []
date_three_time_six_grnd_level = []
date_three_time_six_humidity = []
date_three_time_six_wind_speed = []
date_three_time_six_wind_direction = []

# define day_four_time_one arrays
date_four_time_one = []
date_four_time_one_temp = []
date_four_time_one_temp_min = []
date_four_time_one_temp_max =[]
date_four_time_one_pressure = []
date_four_time_one_sea_level = []
date_four_time_one_grnd_level = []
date_four_time_one_humidity = []
date_four_time_one_wind_speed = []
date_four_time_one_wind_direction = []

# define day_four_time_two arrays
date_four_time_two = []
date_four_time_two_temp = []
date_four_time_two_temp_min = []
date_four_time_two_temp_max =[]
date_four_time_two_pressure = []
date_four_time_two_sea_level = []
date_four_time_two_grnd_level = []
date_four_time_two_humidity = []
date_four_time_two_wind_speed = []
date_four_time_two_wind_direction = []


# define day_four_time_three arrays
date_four_time_three = []
date_four_time_three_temp = []
date_four_time_three_temp_min = []
date_four_time_three_temp_max =[]
date_four_time_three_pressure = []
date_four_time_three_sea_level = []
date_four_time_three_grnd_level = []
date_four_time_three_humidity = []
date_four_time_three_wind_speed = []
date_four_time_three_wind_direction = []

# define day_four_time_four arrays
date_four_time_four = []
date_four_time_four_temp = []
date_four_time_four_temp_min = []
date_four_time_four_temp_max =[]
date_four_time_four_pressure = []
date_four_time_four_sea_level = []
date_four_time_four_grnd_level = []
date_four_time_four_humidity = []
date_four_time_four_wind_speed = []
date_four_time_four_wind_direction = []

# define day_four_time_five arrays
date_four_time_five = []
date_four_time_five_temp = []
date_four_time_five_temp_min = []
date_four_time_five_temp_max =[]
date_four_time_five_pressure = []
date_four_time_five_sea_level = []
date_four_time_five_grnd_level = []
date_four_time_five_humidity = []
date_four_time_five_wind_speed = []
date_four_time_five_wind_direction = []

# define day_four_time_six arrays
date_four_time_six = []
date_four_time_six_temp = []
date_four_time_six_temp_min = []
date_four_time_six_temp_max =[]
date_four_time_six_pressure = []
date_four_time_six_sea_level = []
date_four_time_six_grnd_level = []
date_four_time_six_humidity = []
date_four_time_six_wind_speed = []
date_four_time_six_wind_direction = []

# define day_five_time_one arrays
date_five_time_one = []
date_five_time_one_temp = []
date_five_time_one_temp_min = []
date_five_time_one_temp_max =[]
date_five_time_one_pressure = []
date_five_time_one_sea_level = []
date_five_time_one_grnd_level = []
date_five_time_one_humidity = []
date_five_time_one_wind_speed = []
date_five_time_one_wind_direction = []

# define day_five_time_two arrays
date_five_time_two = []
date_five_time_two_temp = []
date_five_time_two_temp_min = []
date_five_time_two_temp_max =[]
date_five_time_two_pressure = []
date_five_time_two_sea_level = []
date_five_time_two_grnd_level = []
date_five_time_two_humidity = []
date_five_time_two_wind_speed = []
date_five_time_two_wind_direction = []


# define day_five_time_three arrays
date_five_time_three = []
date_five_time_three_temp = []
date_five_time_three_temp_min = []
date_five_time_three_temp_max =[]
date_five_time_three_pressure = []
date_five_time_three_sea_level = []
date_five_time_three_grnd_level = []
date_five_time_three_humidity = []
date_five_time_three_wind_speed = []
date_five_time_three_wind_direction = []

# define day_five_time_four arrays
date_five_time_four = []
date_five_time_four_temp = []
date_five_time_four_temp_min = []
date_five_time_four_temp_max =[]
date_five_time_four_pressure = []
date_five_time_four_sea_level = []
date_five_time_four_grnd_level = []
date_five_time_four_humidity = []
date_five_time_four_wind_speed = []
date_five_time_four_wind_direction = []

# define day_five_time_five arrays
date_five_time_five = []
date_five_time_five_temp = []
date_five_time_five_temp_min = []
date_five_time_five_temp_max =[]
date_five_time_five_pressure = []
date_five_time_five_sea_level = []
date_five_time_five_grnd_level = []
date_five_time_five_humidity = []
date_five_time_five_wind_speed = []
date_five_time_five_wind_direction = []

# define day_five_time_six arrays
date_five_time_six = []
date_five_time_six_temp = []
date_five_time_six_temp_min = []
date_five_time_six_temp_max =[]
date_five_time_six_pressure = []
date_five_time_six_sea_level = []
date_five_time_six_grnd_level = []
date_five_time_six_humidity = []
date_five_time_six_wind_speed = []
date_five_time_six_wind_direction = []

# %%
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()

    #print(response)
    try:
        city_id.append(response['city']['id'])
        city_name.append(response['city']['name'])
        city_lat.append(response['city']['coord']['lat'])
        city_lon.append(response['city']['coord']['lon'])
        country.append(response['city']['country'])
        city_time.append(response['city']['timezone'])
        
        # get the date_one data
        
        date_one_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_one_time_one_temp.append(response['list'][0]['main']['temp'])
        date_one_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_one_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_one_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_one_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_one_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_one_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_one_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_one_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_one_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_one_time_two_temp.append(response['list'][1]['main']['temp'])
        date_one_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_one_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_one_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_one_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_one_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_one_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_one_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_one_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_one_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_one_time_three_temp.append(response['list'][2]['main']['temp'])
        date_one_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_one_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_one_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_one_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_one_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_one_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_one_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_one_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_one_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_one_time_four_temp.append(response['list'][3]['main']['temp'])
        date_one_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_one_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_one_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_one_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_one_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_one_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_one_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_one_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_one_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_one_time_five_temp.append(response['list'][4]['main']['temp'])
        date_one_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_one_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_one_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_one_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_one_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_one_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_one_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_one_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_one_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_one_time_six_temp.append(response['list'][5]['main']['temp'])
        date_one_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_one_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_one_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_one_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_one_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_one_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_one_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_one_time_six_wind_direction.append(response['list'][5]['wind']['deg'])

          # get the date_two data
        
        date_two_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_two_time_one_temp.append(response['list'][0]['main']['temp'])
        date_two_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_two_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_two_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_two_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_two_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_two_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_two_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_two_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_two_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_two_time_two_temp.append(response['list'][1]['main']['temp'])
        date_two_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_two_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_two_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_two_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_two_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_two_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_two_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_two_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_two_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_two_time_three_temp.append(response['list'][2]['main']['temp'])
        date_two_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_two_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_two_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_two_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_two_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_two_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_two_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_two_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_two_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_two_time_four_temp.append(response['list'][3]['main']['temp'])
        date_two_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_two_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_two_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_two_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_two_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_two_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_two_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_two_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_two_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_two_time_five_temp.append(response['list'][4]['main']['temp'])
        date_two_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_two_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_two_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_two_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_two_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_two_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_two_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_two_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_two_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_two_time_six_temp.append(response['list'][5]['main']['temp'])
        date_two_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_two_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_two_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_two_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_two_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_two_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_two_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_two_time_six_wind_direction.append(response['list'][5]['wind']['deg'])

          # get the date_three data
        
        date_three_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_three_time_one_temp.append(response['list'][0]['main']['temp'])
        date_three_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_three_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_three_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_three_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_three_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_three_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_three_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_three_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_three_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_three_time_two_temp.append(response['list'][1]['main']['temp'])
        date_three_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_three_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_three_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_three_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_three_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_three_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_three_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_three_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_three_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_three_time_three_temp.append(response['list'][2]['main']['temp'])
        date_three_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_three_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_three_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_three_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_three_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_three_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_three_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_three_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_three_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_three_time_four_temp.append(response['list'][3]['main']['temp'])
        date_three_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_three_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_three_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_three_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_three_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_three_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_three_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_three_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_three_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_three_time_five_temp.append(response['list'][4]['main']['temp'])
        date_three_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_three_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_three_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_three_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_three_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_three_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_three_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_three_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_three_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_three_time_six_temp.append(response['list'][5]['main']['temp'])
        date_three_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_three_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_three_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_three_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_three_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_three_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_three_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_three_time_six_wind_direction.append(response['list'][5]['wind']['deg'])

          # get the date_four data
        
        date_four_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_four_time_one_temp.append(response['list'][0]['main']['temp'])
        date_four_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_four_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_four_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_four_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_four_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_four_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_four_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_four_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_four_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_four_time_two_temp.append(response['list'][1]['main']['temp'])
        date_four_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_four_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_four_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_four_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_four_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_four_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_four_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_four_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_four_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_four_time_three_temp.append(response['list'][2]['main']['temp'])
        date_four_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_four_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_four_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_four_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_four_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_four_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_four_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_four_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_four_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_four_time_four_temp.append(response['list'][3]['main']['temp'])
        date_four_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_four_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_four_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_four_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_four_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_four_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_four_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_four_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_four_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_four_time_five_temp.append(response['list'][4]['main']['temp'])
        date_four_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_four_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_four_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_four_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_four_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_four_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_four_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_four_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_four_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_four_time_six_temp.append(response['list'][5]['main']['temp'])
        date_four_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_four_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_four_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_four_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_four_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_four_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_four_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_four_time_six_wind_direction.append(response['list'][5]['wind']['deg'])

          # get the date_five data
        
        date_five_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_five_time_one_temp.append(response['list'][0]['main']['temp'])
        date_five_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_five_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_five_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_five_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_five_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_five_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_five_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_five_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_five_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_five_time_two_temp.append(response['list'][1]['main']['temp'])
        date_five_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_five_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_five_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_five_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_five_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_five_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_five_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_five_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_five_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_five_time_three_temp.append(response['list'][2]['main']['temp'])
        date_five_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_five_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_five_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_five_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_five_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_five_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_five_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_five_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_five_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_five_time_four_temp.append(response['list'][3]['main']['temp'])
        date_five_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_five_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_five_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_five_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_five_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_five_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_five_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_five_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_five_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_five_time_five_temp.append(response['list'][4]['main']['temp'])
        date_five_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_five_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_five_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_five_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_five_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_five_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_five_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_five_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_five_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_five_time_six_temp.append(response['list'][5]['main']['temp'])
        date_five_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_five_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_five_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_five_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_five_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_five_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_five_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_five_time_six_wind_direction.append(response['list'][5]['wind']['deg'])

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
print("# citites found in API data: ", len(city_name))
# Out:
# # citites found in API data:  235

# %%
print(city_name)
# Out:
# ['Kabul', 'Tirana', 'Algiers', 'Andorra la Vella', 'Luanda', 'Buenos Aires', 'Yerevan', 'Canberra', 'Vienna', 'Baku', 'Nassau', 'Manama', 'Dhaka', 'Bridgetown', 'Minsk', 'Brussels', 'Belmopan', 'Porto Novo', 'Thimphu', 'La Paz', 'Sarajevo', 'Gaborone', 'Brasilia', 'Bandar Seri Begawan', 'Sofia', 'Ouagadougou', 'Gitega', 'Phnom Penh', 'Yaounde', 'Ottawa', 'Praia', 'Bangui', 'Santiago', 'Beijing', 'Bogota', 'Moroni', 'Kinshasa', 'Brazzaville', 'San Jose', 'Yamoussoukro', 'Zagreb', 'Havana', 'Prague', 'Copenhagen', 'Djibouti', 'Roseau', 'Kabul', 'Tirana', 'Algiers', 'Andorra la Vella', 'Luanda', 'Buenos Aires', 'Yerevan', 'Canberra', 'Vienna', 'Baku', 'Nassau', 'Manama', 'Dhaka', 'Bridgetown', 'Minsk', 'Brussels', 'Belmopan', 'Porto Novo', 'Thimphu', 'La Paz', 'Sarajevo', 'Gaborone', 'Brasilia', 'Bandar Seri Begawan', 'Sofia', 'Ouagadougou', 'Gitega', 'Phnom Penh', 'Yaounde', 'Ottawa', 'Praia', 'Bangui', "N'Djamena", 'Santiago', 'Beijing', 'Bogota', 'Moroni', 'Kinshasa', 'Brazzaville', 
# ...

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    'city_id': city_id,
    'city_name': city_name,
    'city_lat': city_lat,
    'city_lon': city_lon,
    'country': country,
    'city_time': city_time,
    'date_one_time_one': date_one_time_one,
    'date_one_time_one_temp': date_one_time_one_temp,
    'date_one_time_one_temp_min': date_one_time_one_temp_min,
    'date_one_time_one_temp_max': date_one_time_one_temp_max,
    'date_one_time_one_pressure': date_one_time_one_pressure,
    'date_one_time_one_sea_level': date_one_time_one_sea_level,
    'date_one_time_one_grnd_level': date_one_time_one_grnd_level,
    'date_one_time_one_humidity': date_one_time_one_humidity,
    'date_one_time_one_wind_speed': date_one_time_one_wind_speed,
    'date_one_time_one_direction': date_one_time_one_wind_direction,
    'date_one_time_two': date_one_time_two,
    'date_one_time_two_temp': date_one_time_two_temp,
    'date_one_time_two_temp_min': date_one_time_two_temp_min,
    'date_one_time_two_temp_max': date_one_time_two_temp_max,
    'date_one_time_two_pressure': date_one_time_two_pressure,
    'date_one_time_two_sea_level': date_one_time_two_sea_level,
    'date_one_time_two_grnd_level': date_one_time_two_grnd_level,
    'date_one_time_two_humidity': date_one_time_two_humidity,
    'date_one_time_two_wind_speed': date_one_time_two_wind_speed,
    'date_one_time_two_direction': date_one_time_two_wind_direction,
    'date_one_time_three': date_one_time_three,
    'date_one_time_three_temp': date_one_time_three_temp,
    'date_one_time_three_temp_min': date_one_time_three_temp_min,
    'date_one_time_three_temp_max': date_one_time_three_temp_max,
    'date_one_time_three_pressure': date_one_time_three_pressure,
    'date_one_time_three_sea_level': date_one_time_three_sea_level,
    'date_one_time_three_grnd_level': date_one_time_three_grnd_level,
    'date_one_time_three_humidity': date_one_time_three_humidity,
    'date_one_time_three_wind_speed': date_one_time_three_wind_speed,
    'date_one_time_three_direction': date_one_time_three_wind_direction,
    'date_one_time_four': date_one_time_four,
    'date_one_time_four_temp': date_one_time_four_temp,
    'date_one_time_four_temp_min': date_one_time_four_temp_min,
    'date_one_time_four_temp_max': date_one_time_four_temp_max,
    'date_one_time_four_pressure': date_one_time_four_pressure,
    'date_one_time_four_sea_level': date_one_time_four_sea_level,
    'date_one_time_four_grnd_level': date_one_time_four_grnd_level,
    'date_one_time_four_humidity': date_one_time_four_humidity,
    'date_one_time_four_wind_speed': date_one_time_four_wind_speed,
    'date_one_time_four_direction': date_one_time_four_wind_direction,
    'date_one_time_five': date_one_time_five,
    'date_one_time_five_temp': date_one_time_five_temp,
    'date_one_time_five_temp_min': date_one_time_five_temp_min,
    'date_one_time_five_temp_max': date_one_time_five_temp_max,
    'date_one_time_five_pressure': date_one_time_five_pressure,
    'date_one_time_five_sea_level': date_one_time_five_sea_level,
    'date_one_time_five_grnd_level': date_one_time_five_grnd_level,
    'date_one_time_five_humidity': date_one_time_five_humidity,
    'date_one_time_five_wind_speed': date_one_time_five_wind_speed,
    'date_one_time_five_direction': date_one_time_five_wind_direction,
    'date_one_time_six': date_one_time_six,
    'date_one_time_six_temp': date_one_time_six_temp,
    'date_one_time_six_temp_min': date_one_time_six_temp_min,
    'date_one_time_six_temp_max': date_one_time_six_temp_max,
    'date_one_time_six_pressure': date_one_time_six_pressure,
    'date_one_time_six_sea_level': date_one_time_six_sea_level,
    'date_one_time_six_grnd_level': date_one_time_six_grnd_level,
    'date_one_time_six_humidity': date_one_time_six_humidity,
    'date_one_time_six_wind_speed': date_one_time_six_wind_speed,
    'date_one_time_six_direction': date_one_time_six_wind_direction,
    'date_two_time_one': date_two_time_one,
    'date_two_time_one_temp': date_two_time_one_temp,
    'date_two_time_one_temp_min': date_two_time_one_temp_min,
    'date_two_time_one_temp_max': date_two_time_one_temp_max,
    'date_two_time_one_pressure': date_two_time_one_pressure,
    'date_two_time_one_sea_level': date_two_time_one_sea_level,
    'date_two_time_one_grnd_level': date_two_time_one_grnd_level,
    'date_two_time_one_humidity': date_two_time_one_humidity,
    'date_two_time_one_wind_speed': date_two_time_one_wind_speed,
    'date_two_time_one_direction': date_two_time_one_wind_direction,
    'date_two_time_two': date_two_time_two,
    'date_two_time_two_temp': date_two_time_two_temp,
    'date_two_time_two_temp_min': date_two_time_two_temp_min,
    'date_two_time_two_temp_max': date_two_time_two_temp_max,
    'date_two_time_two_pressure': date_two_time_two_pressure,
    'date_two_time_two_sea_level': date_two_time_two_sea_level,
    'date_two_time_two_grnd_level': date_two_time_two_grnd_level,
    'date_two_time_two_humidity': date_two_time_two_humidity,
    'date_two_time_two_wind_speed': date_two_time_two_wind_speed,
    'date_two_time_two_direction': date_two_time_two_wind_direction,
    'date_two_time_three': date_two_time_three,
    'date_two_time_three_temp': date_two_time_three_temp,
    'date_two_time_three_temp_min': date_two_time_three_temp_min,
    'date_two_time_three_temp_max': date_two_time_three_temp_max,
    'date_two_time_three_pressure': date_two_time_three_pressure,
    'date_two_time_three_sea_level': date_two_time_three_sea_level,
    'date_two_time_three_grnd_level': date_two_time_three_grnd_level,
    'date_two_time_three_humidity': date_two_time_three_humidity,
    'date_two_time_three_wind_speed': date_two_time_three_wind_speed,
    'date_two_time_three_direction': date_two_time_three_wind_direction,
    'date_two_time_four': date_two_time_four,
    'date_two_time_four_temp': date_two_time_four_temp,
    'date_two_time_four_temp_min': date_two_time_four_temp_min,
    'date_two_time_four_temp_max': date_two_time_four_temp_max,
    'date_two_time_four_pressure': date_two_time_four_pressure,
    'date_two_time_four_sea_level': date_two_time_four_sea_level,
    'date_two_time_four_grnd_level': date_two_time_four_grnd_level,
    'date_two_time_four_humidity': date_two_time_four_humidity,
    'date_two_time_four_wind_speed': date_two_time_four_wind_speed,
    'date_two_time_four_direction': date_two_time_four_wind_direction,
    'date_two_time_five': date_two_time_five,
    'date_two_time_five_temp': date_two_time_five_temp,
    'date_two_time_five_temp_min': date_two_time_five_temp_min,
    'date_two_time_five_temp_max': date_two_time_five_temp_max,
    'date_two_time_five_pressure': date_two_time_five_pressure,
    'date_two_time_five_sea_level': date_two_time_five_sea_level,
    'date_two_time_five_grnd_level': date_two_time_five_grnd_level,
    'date_two_time_five_humidity': date_two_time_five_humidity,
    'date_two_time_five_wind_speed': date_two_time_five_wind_speed,
    'date_two_time_five_direction': date_two_time_five_wind_direction,
    'date_two_time_six': date_two_time_six,
    'date_two_time_six_temp': date_two_time_six_temp,
    'date_two_time_six_temp_min': date_two_time_six_temp_min,
    'date_two_time_six_temp_max': date_two_time_six_temp_max,
    'date_two_time_six_pressure': date_two_time_six_pressure,
    'date_two_time_six_sea_level': date_two_time_six_sea_level,
    'date_two_time_six_grnd_level': date_two_time_six_grnd_level,
    'date_two_time_six_humidity': date_two_time_six_humidity,
    'date_two_time_six_wind_speed': date_two_time_six_wind_speed,
    'date_two_time_six_direction': date_two_time_six_wind_direction,
    'date_three_time_one': date_three_time_one,
    'date_three_time_one_temp': date_three_time_one_temp,
    'date_three_time_one_temp_min': date_three_time_one_temp_min,
    'date_three_time_one_temp_max': date_three_time_one_temp_max,
    'date_three_time_one_pressure': date_three_time_one_pressure,
    'date_three_time_one_sea_level': date_three_time_one_sea_level,
    'date_three_time_one_grnd_level': date_three_time_one_grnd_level,
    'date_three_time_one_humidity': date_three_time_one_humidity,
    'date_three_time_one_wind_speed': date_three_time_one_wind_speed,
    'date_three_time_one_direction': date_three_time_one_wind_direction,
    'date_three_time_two': date_three_time_two,
    'date_three_time_two_temp': date_three_time_two_temp,
    'date_three_time_two_temp_min': date_three_time_two_temp_min,
    'date_three_time_two_temp_max': date_three_time_two_temp_max,
    'date_three_time_two_pressure': date_three_time_two_pressure,
    'date_three_time_two_sea_level': date_three_time_two_sea_level,
    'date_three_time_two_grnd_level': date_three_time_two_grnd_level,
    'date_three_time_two_humidity': date_three_time_two_humidity,
    'date_three_time_two_wind_speed': date_three_time_two_wind_speed,
    'date_three_time_two_direction': date_three_time_two_wind_direction,
    'date_three_time_three': date_three_time_three,
    'date_three_time_three_temp': date_three_time_three_temp,
    'date_three_time_three_temp_min': date_three_time_three_temp_min,
    'date_three_time_three_temp_max': date_three_time_three_temp_max,
    'date_three_time_three_pressure': date_three_time_three_pressure,
    'date_three_time_three_sea_level': date_three_time_three_sea_level,
    'date_three_time_three_grnd_level': date_three_time_three_grnd_level,
    'date_three_time_three_humidity': date_three_time_three_humidity,
    'date_three_time_three_wind_speed': date_three_time_three_wind_speed,
    'date_three_time_three_direction': date_three_time_three_wind_direction,
    'date_three_time_four': date_three_time_four,
    'date_three_time_four_temp': date_three_time_four_temp,
    'date_three_time_four_temp_min': date_three_time_four_temp_min,
    'date_three_time_four_temp_max': date_three_time_four_temp_max,
    'date_three_time_four_pressure': date_three_time_four_pressure,
    'date_three_time_four_sea_level': date_three_time_four_sea_level,
    'date_three_time_four_grnd_level': date_three_time_four_grnd_level,
    'date_three_time_four_humidity': date_three_time_four_humidity,
    'date_three_time_four_wind_speed': date_three_time_four_wind_speed,
    'date_three_time_four_direction': date_three_time_four_wind_direction,
    'date_three_time_five': date_three_time_five,
    'date_three_time_five_temp': date_three_time_five_temp,
    'date_three_time_five_temp_min': date_three_time_five_temp_min,
    'date_three_time_five_temp_max': date_three_time_five_temp_max,
    'date_three_time_five_pressure': date_three_time_five_pressure,
    'date_three_time_five_sea_level': date_three_time_five_sea_level,
    'date_three_time_five_grnd_level': date_three_time_five_grnd_level,
    'date_three_time_five_humidity': date_three_time_five_humidity,
    'date_three_time_five_wind_speed': date_three_time_five_wind_speed,
    'date_three_time_five_direction': date_three_time_five_wind_direction,
    'date_three_time_six': date_three_time_six,
    'date_three_time_six_temp': date_three_time_six_temp,
    'date_three_time_six_temp_min': date_three_time_six_temp_min,
    'date_three_time_six_temp_max': date_three_time_six_temp_max,
    'date_three_time_six_pressure': date_three_time_six_pressure,
    'date_three_time_six_sea_level': date_three_time_six_sea_level,
    'date_three_time_six_grnd_level': date_three_time_six_grnd_level,
    'date_three_time_six_humidity': date_three_time_six_humidity,
    'date_three_time_six_wind_speed': date_three_time_six_wind_speed,
    'date_three_time_six_direction': date_three_time_six_wind_direction,
    'date_four_time_one': date_four_time_one,
    'date_four_time_one_temp': date_four_time_one_temp,
    'date_four_time_one_temp_min': date_four_time_one_temp_min,
    'date_four_time_one_temp_max': date_four_time_one_temp_max,
    'date_four_time_one_pressure': date_four_time_one_pressure,
    'date_four_time_one_sea_level': date_four_time_one_sea_level,
    'date_four_time_one_grnd_level': date_four_time_one_grnd_level,
    'date_four_time_one_humidity': date_four_time_one_humidity,
    'date_four_time_one_wind_speed': date_four_time_one_wind_speed,
    'date_four_time_one_direction': date_four_time_one_wind_direction,
    'date_four_time_two': date_four_time_two,
    'date_four_time_two_temp': date_four_time_two_temp,
    'date_four_time_two_temp_min': date_four_time_two_temp_min,
    'date_four_time_two_temp_max': date_four_time_two_temp_max,
    'date_four_time_two_pressure': date_four_time_two_pressure,
    'date_four_time_two_sea_level': date_four_time_two_sea_level,
    'date_four_time_two_grnd_level': date_four_time_two_grnd_level,
    'date_four_time_two_humidity': date_four_time_two_humidity,
    'date_four_time_two_wind_speed': date_four_time_two_wind_speed,
    'date_four_time_two_direction': date_four_time_two_wind_direction,
    'date_four_time_three': date_four_time_three,
    'date_four_time_three_temp': date_four_time_three_temp,
    'date_four_time_three_temp_min': date_four_time_three_temp_min,
    'date_four_time_three_temp_max': date_four_time_three_temp_max,
    'date_four_time_three_pressure': date_four_time_three_pressure,
    'date_four_time_three_sea_level': date_four_time_three_sea_level,
    'date_four_time_three_grnd_level': date_four_time_three_grnd_level,
    'date_four_time_three_humidity': date_four_time_three_humidity,
    'date_four_time_three_wind_speed': date_four_time_three_wind_speed,
    'date_four_time_three_direction': date_four_time_three_wind_direction,
    'date_four_time_four': date_four_time_four,
    'date_four_time_four_temp': date_four_time_four_temp,
    'date_four_time_four_temp_min': date_four_time_four_temp_min,
    'date_four_time_four_temp_max': date_four_time_four_temp_max,
    'date_four_time_four_pressure': date_four_time_four_pressure,
    'date_four_time_four_sea_level': date_four_time_four_sea_level,
    'date_four_time_four_grnd_level': date_four_time_four_grnd_level,
    'date_four_time_four_humidity': date_four_time_four_humidity,
    'date_four_time_four_wind_speed': date_four_time_four_wind_speed,
    'date_four_time_four_direction': date_four_time_four_wind_direction,
    'date_four_time_five': date_four_time_five,
    'date_four_time_five_temp': date_four_time_five_temp,
    'date_four_time_five_temp_min': date_four_time_five_temp_min,
    'date_four_time_five_temp_max': date_four_time_five_temp_max,
    'date_four_time_five_pressure': date_four_time_five_pressure,
    'date_four_time_five_sea_level': date_four_time_five_sea_level,
    'date_four_time_five_grnd_level': date_four_time_five_grnd_level,
    'date_four_time_five_humidity': date_four_time_five_humidity,
    'date_four_time_five_wind_speed': date_four_time_five_wind_speed,
    'date_four_time_five_direction': date_four_time_five_wind_direction,
    'date_four_time_six': date_four_time_six,
    'date_four_time_six_temp': date_four_time_six_temp,
    'date_four_time_six_temp_min': date_four_time_six_temp_min,
    'date_four_time_six_temp_max': date_four_time_six_temp_max,
    'date_four_time_six_pressure': date_four_time_six_pressure,
    'date_four_time_six_sea_level': date_four_time_six_sea_level,
    'date_four_time_six_grnd_level': date_four_time_six_grnd_level,
    'date_four_time_six_humidity': date_four_time_six_humidity,
    'date_four_time_six_wind_speed': date_four_time_six_wind_speed,
    'date_four_time_six_direction': date_four_time_six_wind_direction,
    'date_five_time_one': date_five_time_one,
    'date_five_time_one_temp': date_five_time_one_temp,
    'date_five_time_one_temp_min': date_five_time_one_temp_min,
    'date_five_time_one_temp_max': date_five_time_one_temp_max,
    'date_five_time_one_pressure': date_five_time_one_pressure,
    'date_five_time_one_sea_level': date_five_time_one_sea_level,
    'date_five_time_one_grnd_level': date_five_time_one_grnd_level,
    'date_five_time_one_humidity': date_five_time_one_humidity,
    'date_five_time_one_wind_speed': date_five_time_one_wind_speed,
    'date_five_time_one_direction': date_five_time_one_wind_direction,
    'date_five_time_two': date_five_time_two,
    'date_five_time_two_temp': date_five_time_two_temp,
    'date_five_time_two_temp_min': date_five_time_two_temp_min,
    'date_five_time_two_temp_max': date_five_time_two_temp_max,
    'date_five_time_two_pressure': date_five_time_two_pressure,
    'date_five_time_two_sea_level': date_five_time_two_sea_level,
    'date_five_time_two_grnd_level': date_five_time_two_grnd_level,
    'date_five_time_two_humidity': date_five_time_two_humidity,
    'date_five_time_two_wind_speed': date_five_time_two_wind_speed,
    'date_five_time_two_direction': date_five_time_two_wind_direction,
    'date_five_time_three': date_five_time_three,
    'date_five_time_three_temp': date_five_time_three_temp,
    'date_five_time_three_temp_min': date_five_time_three_temp_min,
    'date_five_time_three_temp_max': date_five_time_three_temp_max,
    'date_five_time_three_pressure': date_five_time_three_pressure,
    'date_five_time_three_sea_level': date_five_time_three_sea_level,
    'date_five_time_three_grnd_level': date_five_time_three_grnd_level,
    'date_five_time_three_humidity': date_five_time_three_humidity,
    'date_five_time_three_wind_speed': date_five_time_three_wind_speed,
    'date_five_time_three_direction': date_five_time_three_wind_direction,
    'date_five_time_four': date_five_time_four,
    'date_five_time_four_temp': date_five_time_four_temp,
    'date_five_time_four_temp_min': date_five_time_four_temp_min,
    'date_five_time_four_temp_max': date_five_time_four_temp_max,
    'date_five_time_four_pressure': date_five_time_four_pressure,
    'date_five_time_four_sea_level': date_five_time_four_sea_level,
    'date_five_time_four_grnd_level': date_five_time_four_grnd_level,
    'date_five_time_four_humidity': date_five_time_four_humidity,
    'date_five_time_four_wind_speed': date_five_time_four_wind_speed,
    'date_five_time_four_direction': date_five_time_four_wind_direction,
    'date_five_time_five': date_five_time_five,
    'date_five_time_five_temp': date_five_time_five_temp,
    'date_five_time_five_temp_min': date_five_time_five_temp_min,
    'date_five_time_five_temp_max': date_five_time_five_temp_max,
    'date_five_time_five_pressure': date_five_time_five_pressure,
    'date_five_time_five_sea_level': date_five_time_five_sea_level,
    'date_five_time_five_grnd_level': date_five_time_five_grnd_level,
    'date_five_time_five_humidity': date_five_time_five_humidity,
    'date_five_time_five_wind_speed': date_five_time_five_wind_speed,
    'date_five_time_five_direction': date_five_time_five_wind_direction,
    'date_five_time_six': date_five_time_six,
    'date_five_time_six_temp': date_five_time_six_temp,
    'date_five_time_six_temp_min': date_five_time_six_temp_min,
    'date_five_time_six_temp_max': date_five_time_six_temp_max,
    'date_five_time_six_pressure': date_five_time_six_pressure,
    'date_five_time_six_sea_level': date_five_time_six_sea_level,
    'date_five_time_six_grnd_level': date_five_time_six_grnd_level,
    'date_five_time_six_humidity': date_five_time_six_humidity,
    'date_five_time_six_wind_speed': date_five_time_six_wind_speed,
    'date_five_time_six_direction': date_five_time_six_wind_direction

}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#    city_id         city_name  city_lat  city_lon country  city_time  \
# 0  1138958             Kabul   34.5260   69.1776      AF      16200
# 1  3183875            Tirana   41.3275   19.8189      AL       3600
# 2  4335045           Algiers   29.9413  -90.0376      US     -21600
# 3  3041563  Andorra la Vella   42.5069    1.5212      FR       3600
# 4  2240449            Luanda   -8.8272   13.2437      AO       3600
#
#      date_one_time_one  date_one_time_one_temp  date_one_time_one_temp_min  \
# 0  2020-01-04 16:00:00                  268.03                      268.03
# 1  2020-01-04 16:00:00                  277.31                      275.26
# 2  2020-01-04 16:00:00                  290.07                      289.16
# 3  2020-01-04 16:00:00                  276.62                      273.46
# 4  2020-01-04 16:00:00                  298.61                      298.61
#
#    date_one_time_one_temp_max  ...   date_five_time_six  \
# ...

# %%
weather_data.to_csv('weather_data.csv')

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["city_name"], weather_data["date_one_time_one_temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
